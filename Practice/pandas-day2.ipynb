# %% [markdown]
# ### Pandas Day 2

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49  \
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill'] > 40
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'] > 45]
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person
# 59        48.27   6.73  Male     No  Sat  Dinner     4             12.07  \
# 156       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 170    Gregory Clark  5473850968388236    Sat1954
# 182     Jose Parsons  4112207559459910    Sun2337
# 212  Alex Williamson      676218815212    Sat4590

# %%
df[235:]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04  \
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 235    Sean Gonzalez  3534021246117605    Sat4615
# 236    Matthew Myers  3543676378973965    Sat5032
# 237     Thomas Brown  4284722681265508    Sat2929
# ...

# %%
df.set_index('Payment ID')
# Out:
#             total_bill   tip     sex smoker   day    time  size
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2  \
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
def last_four_digits(num):
    return str(num)[-3:]

last_four_digits(123456789)
# Out:
# '789'

# %%
df['last_four_num'] = df['CC Number'].apply(last_four_digits)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four_num
# 0  Christy Cunningham  3560325168603410    Sun2959           410
# 1      Douglas Tucker  4478071379779230    Sun4608           230
# 2      Travis Walters  6011812112971322    Sun4458           322
# 3    Nathaniel Harris  4676137647685994    Sun5260           994
# 4        Tonya Carter  4832732618637221    Sun2251           221

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif price > 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp)
df.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
# ...

# %%
def quality(total_bill, tip):
    if tip / total_bill > 0.25:
        return 'Generous'
    else:
        return 'other'

# %%
df['tip_quality'] = df[['total_bill', 'tip']].apply(lambda df : quality(df['total_bill'], df['tip']), axis=1)

# %%
df['tip_quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
df[(df['tip'] /df['total_bill']) > 0.25].head(5)
# Out:
#      total_bill  tip     sex smoker   day    time  size  price_per_person
# 51        10.29  2.6  Female     No   Sun  Dinner     2              5.14  \
# 67         3.07  1.0  Female    Yes   Sat  Dinner     1              3.07
# 93        16.32  4.3  Female    Yes   Fri  Dinner     2              8.16
# 109       14.31  4.0  Female    Yes   Sat  Dinner     2              7.16
# 149        7.51  2.0    Male     No  Thur   Lunch     2              3.76
#
#           Payer Name         CC Number Payment ID last_four_num yelp
# 51    Jessica Ibarra     4999759463713    Sun4474           713   $$  \
# 67     Tiffany Brock  4359488526995267    Sat3455           267    $
# 93    Natalie Nguyen  5181236182893396    Fri6963           396   $$
# 109  Amanda Anderson   375638820334211    Sat2614           211   $$
# 149   Daniel Robbins  4823139288341889   Thur6321           889    $
#
#     tip_quality
# 51     Generous
# 67     Generous
# 93     Generous
# 109    Generous
# 149    Generous

# %%
df.sort_values('total_bill', ascending=False).head(5)
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94  \
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 59        48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 156       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#           Payer Name         CC Number Payment ID last_four_num yelp
# 170    Gregory Clark  5473850968388236    Sat1954           236  $$$  \
# 212  Alex Williamson      676218815212    Sat4590           212  $$$
# 59       Brian Ortiz  6596453823950595    Sat8139           595  $$$
# 156    Ryan Gonzales  3523151482063321    Sun7518           321  $$$
# 182     Jose Parsons  4112207559459910    Sun2337           910  $$$
#
#     tip_quality
# 170       other
# 212       other
# 59        other
# 156       other
# 182       other

# %%
df.sort_values(['tip', 'size']).head(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07  \
# 111        7.25  1.00  Female     No  Sat  Dinner     1              7.25
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID last_four_num yelp
# 67        Tiffany Brock  4359488526995267    Sat3455           267    $  \
# 111         Terri Jones  3559221007826887    Sat4801           887    $
# 92         Leah Ramirez  3508911676966392    Fri3780           392    $
# 236       Matthew Myers  3543676378973965    Sat5032           965   $$
# 0    Christy Cunningham  3560325168603410    Sun2959           410   $$
#
#     tip_quality
# 67     Generous
# 111       other
# 92        other
# 236       other
# ...

# %%
df['tip'].idxmax()
# Out:
# 170

# %%
df.iloc[df['tip'].idxmax()]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# last_four_num                    236
# yelp                             $$$
# tip_quality                    other
# Name: 170, dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['sex'].replace('Female', 'F')
# Out:
# 0         F
# 1      Male
# 2      Male
# 3      Male
# 4         F
#        ...
# 239    Male
# 240       F
# 241    Male
# 242    Male
# 243       F
# Name: sex, Length: 244, dtype: object

# %%
df['sex'].replace(['Female', 'Male'], ['F', 'M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object
